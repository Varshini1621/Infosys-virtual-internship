# %% [markdown]
# Introduction to Pandas

# %%
# Importing pandas library
import pandas as pd

# %%
## EXAMPLE-1
# Creating a Series from a list
data = [10, 20, 30, 40]
my_series = pd.Series(data)
print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#ex-2
my_series = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(my_series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#EX
data = {'Name': ['Tom', 'Anna'], 'Age': [28, 24]}
df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0   Tom   28
# 1  Anna   24

# %%
from google.colab import files
import pandas as pd

# Upload CSV file
uploaded = files.upload()

# Read CSV (replace 'your_file.csv' with the uploaded filename)
df = pd.read_csv("database.csv")
print(df.head())
# Out:
#      <input type="file" id="files-608c8242-fac7-40bd-9d50-86511253a8ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-608c8242-fac7-40bd-9d50-86511253a8ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.tail()
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake  12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df.sample(5)
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 16014  10/16/2002  10:12:21   51.9520   157.3230  Earthquake  102.4
# 1992   07/17/1971  05:32:44    7.0450    94.6600  Earthquake  135.0
# 7165   09/05/1984  08:18:13  -21.1380  -179.0150  Earthquake  621.5
# 7506   04/25/1985  15:30:24    8.4940    93.6530  Earthquake   33.0
# 23349  11/22/2016  05:13:35  -42.9298   173.0041  Earthquake   10.0
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 16014          NaN                   589.0        6.2            MWC  ...
# 1992           NaN                     NaN        6.2             MW  ...
# 7165           3.0                     NaN        5.5             MW  ...
# 7506           NaN                     NaN        5.6             MW  ...
# 23349          1.7                     NaN        5.5            MWW  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.size
# Out:
# 491652

# %%
df['Status'].value_counts()
# Out:
# Status
# Reviewed     20773
# Automatic     2639
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# 0                        True      False           False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date                          23412
# Time                          23412
# Latitude                      23412
# Longitude                     23412
# Type                          23412
# Depth                         23412
# Depth Error                    4461
# Depth Seismic Stations         7097
# Magnitude                     23412
# Magnitude Type                23409
# Magnitude Error                 327
# Magnitude Seismic Stations     2564
# Azimuthal Gap                  7299
# Horizontal Distance            1604
# Horizontal Error               1156
# Root Mean Square              17352
# ID                            23412
# Source                        23412
# Location Source               23412
# Magnitude Source              23412
# Status                        23412
# dtype: int64

# %% [markdown]
# **DAY2**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
temp_df = df[['Latitude', 'Longitude','Magnitude','Root Mean Square','Status']]
temp_df.sample(10)
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 20598   39.0840   142.2640        5.8              0.71   Reviewed
# 16206  -15.3240  -173.5080        6.2              0.85   Reviewed
# 2543    -2.9890   139.0800        6.0               NaN  Automatic
# 11652   -6.0130   146.0610        6.0              1.20   Reviewed
# 22727   52.2572  -169.3458        5.9              0.86   Reviewed
# 8148   -16.3160  -173.0500        5.5              1.00   Reviewed
# 690    -58.3750   -26.9560        6.0               NaN  Automatic
# 21646  -30.7740  -178.1230        5.9              0.84   Reviewed
# 806     -8.0460   112.9810        5.7               NaN  Automatic
# 9964   -35.2530  -104.1420        5.7              1.20   Reviewed

# %%
temp_df['Latitude']
# Out:
# 0        19.2460
# 1         1.8630
# 2       -20.5790
# 3       -59.0760
# 4        11.9380
#           ...
# 23407    38.3917
# 23408    38.3777
# 23409    36.9179
# 23410    -9.0283
# 23411    37.3973
# Name: Latitude, Length: 23412, dtype: float64

# %%
temp_df.loc[100, 'Latitude']
# Out:
# np.float64(-32.522)

# %%
temp_df.iloc[100, 0]
# Out:
# np.float64(-32.522)

# %%
temp_df.loc[0:10, ['Latitude', 'Longitude']]
# Out:
#     Latitude  Longitude
# 0     19.246    145.616
# 1      1.863    127.352
# 2    -20.579   -173.972
# 3    -59.076    -23.557
# 4     11.938    126.427
# 5    -13.405    166.629
# 6     27.357     87.867
# 7    -13.309    166.212
# 8    -56.452    -27.043
# 9    -24.563    178.487
# 10    -6.807    108.988

# %%
temp_df.iloc[0:11, 0:2]
# Out:
#     Latitude  Longitude
# 0     19.246    145.616
# 1      1.863    127.352
# 2    -20.579   -173.972
# 3    -59.076    -23.557
# 4     11.938    126.427
# 5    -13.405    166.629
# 6     27.357     87.867
# 7    -13.309    166.212
# 8    -56.452    -27.043
# 9    -24.563    178.487
# 10    -6.807    108.988

# %%
#Filtering
temp_df[temp_df['Latitude'] > 25]
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 6       27.3570    87.8670        5.9               NaN  Automatic
# 12      54.6360   161.7030        5.5               NaN  Automatic
# 14      37.5230    73.2510        6.0               NaN  Automatic
# 16      51.2510   178.7150        8.7               NaN  Automatic
# 17      51.6390   175.0550        6.0               NaN  Automatic
# ...         ...        ...        ...               ...        ...
# 23406   38.3754  -118.8977        5.6            0.1988   Reviewed
# 23407   38.3917  -118.8941        5.6            0.1898   Reviewed
# 23408   38.3777  -118.8957        5.5            0.2187   Reviewed
# 23409   36.9179   140.4262        5.9            1.5200   Reviewed
# 23411   37.3973   141.4103        5.5            0.9100   Reviewed
#
# [5953 rows x 5 columns]

# %%
temp_df[(temp_df['Latitude'] > 25) & (temp_df['Longitude'] > 25)]
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 6       27.3570    87.8670        5.9               NaN  Automatic
# 12      54.6360   161.7030        5.5               NaN  Automatic
# 14      37.5230    73.2510        6.0               NaN  Automatic
# 16      51.2510   178.7150        8.7               NaN  Automatic
# 17      51.6390   175.0550        6.0               NaN  Automatic
# ...         ...        ...        ...               ...        ...
# 23367   43.8229    86.3451        6.0              0.82   Reviewed
# 23396   37.1442    84.9583        5.6              0.83   Reviewed
# 23405   45.7192    26.5230        5.6              0.78   Reviewed
# 23409   36.9179   140.4262        5.9              1.52   Reviewed
# 23411   37.3973   141.4103        5.5              0.91   Reviewed
#
# [4409 rows x 5 columns]

# %%
temp_df.sample(10)
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square    Status
# 8812    -60.069    -26.522        5.5              1.00  Reviewed
# 12004    -7.532    127.770        6.5              1.10  Reviewed
# 14617   -28.500    -71.221        5.7              0.97  Reviewed
# 19614    23.501    123.499        6.7              1.01  Reviewed
# 6232      7.653    -72.197        5.5              0.80  Reviewed
# 15552    -7.506    127.739        6.0              0.94  Reviewed
# 19505   -24.381    178.846        5.5              0.85  Reviewed
# 6582     17.631    -46.529        5.7              1.20  Reviewed
# 3404    -10.070    -75.278        5.5               NaN  Reviewed
# 3530    -14.712    167.244        5.7               NaN  Reviewed

# %%
temp_df.sample(10)
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 84      -29.998   -177.968        6.0               NaN  Automatic
# 1345     43.875    148.500        5.8               NaN  Automatic
# 5353    -16.760   -179.984        6.9               NaN   Reviewed
# 6605     45.344    150.380        5.7              0.70   Reviewed
# 18316    46.897    151.770        5.6              0.81   Reviewed
# 10769    43.202    146.572        5.6              0.90   Reviewed
# 5657     -1.380    -77.686        5.5               NaN   Reviewed
# 16322    -5.448    151.878        5.7              0.78   Reviewed
# 12872    27.291    100.276        6.6              1.20   Reviewed
# 8778    -19.648    175.944        5.5              1.50   Reviewed

# %%
temp_df['Mag-1'] = temp_df['Magnitude'] - 1
# Out:
# /tmp/ipython-input-759490576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['Mag-1'] = temp_df['Magnitude'] - 1

# %%
temp_df.sample(10)
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square    Status  Mag-1
# 14365    45.449    151.630        5.9              0.83  Reviewed    4.9
# 13165    13.514    -91.281        5.7              1.11  Reviewed    4.7
# 14797   -52.455     13.544        5.8              1.02  Reviewed    4.8
# 11693    14.807    -93.972        5.6              1.20  Reviewed    4.6
# 15503   -55.573   -123.395        5.6              1.13  Reviewed    4.6
# 5416     37.721    133.414        5.5               NaN  Reviewed    4.5
# 5068     42.782    131.197        5.7               NaN  Reviewed    4.7
# 17437    51.185    179.548        5.6              0.71  Reviewed    4.6
# 16660    34.774     73.216        5.5              0.86  Reviewed    4.5
# 9719    -50.053    162.592        6.3              1.30  Reviewed    5.3

# %%
temp_df.drop(columns=['Mag-1'])
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 0       19.2460   145.6160        6.0               NaN  Automatic
# 1        1.8630   127.3520        5.8               NaN  Automatic
# 2      -20.5790  -173.9720        6.2               NaN  Automatic
# 3      -59.0760   -23.5570        5.8               NaN  Automatic
# 4       11.9380   126.4270        5.8               NaN  Automatic
# ...         ...        ...        ...               ...        ...
# 23407   38.3917  -118.8941        5.6            0.1898   Reviewed
# 23408   38.3777  -118.8957        5.5            0.2187   Reviewed
# 23409   36.9179   140.4262        5.9            1.5200   Reviewed
# 23410   -9.0283   118.6639        6.3            1.4300   Reviewed
# 23411   37.3973   141.4103        5.5            0.9100   Reviewed
#
# [23412 rows x 5 columns]

# %%
temp_df.drop(columns=['Mag-1'], inplace=True)
# Out:
# /tmp/ipython-input-1699929037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df.drop(columns=['Mag-1'], inplace=True)

# %%
temp_df.sample(10)
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square    Status
# 11243    52.126    178.761        5.5              1.00  Reviewed
# 11933     7.646     94.279        5.9              1.00  Reviewed
# 3060    -54.043      7.105        5.6               NaN  Reviewed
# 18258   -55.791   -123.448        5.6              1.20  Reviewed
# 9305     36.399    141.751        5.7              0.90  Reviewed
# 3695     18.225   -102.185        5.9               NaN  Reviewed
# 4978     -5.441    152.005        5.9               NaN  Reviewed
# 3736    -11.226    166.338        5.5               NaN  Reviewed
# 13579    32.334     59.957        5.6              1.37  Reviewed
# 5378      2.614    -79.215        5.8               NaN  Reviewed

# %%
temp_df.isnull()
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square  Status
# 0         False      False      False              True   False
# 1         False      False      False              True   False
# 2         False      False      False              True   False
# 3         False      False      False              True   False
# 4         False      False      False              True   False
# ...         ...        ...        ...               ...     ...
# 23407     False      False      False             False   False
# 23408     False      False      False             False   False
# 23409     False      False      False             False   False
# 23410     False      False      False             False   False
# 23411     False      False      False             False   False
#
# [23412 rows x 5 columns]

# %%
temp_df.isnull().sum()
# Out:
# Latitude               0
# Longitude              0
# Magnitude              0
# Root Mean Square    6060
# Status                 0
# dtype: int64

# %%
temp_df.isnull().sum()/temp_df.shape[0] * 100
# Out:
# Latitude             0.000000
# Longitude            0.000000
# Magnitude            0.000000
# Root Mean Square    25.884162
# Status               0.000000
# dtype: float64

# %%
df_1 = temp_df[['Latitude', 'Root Mean Square', 'Status']] # This will create a new DataFrame df_1 with only the specified columns
df_1.shape
# Out:
# (23412, 3)

# %%
df_1.dropna()
# Out:
#         Latitude  Root Mean Square    Status
# 489    31.039500            0.6000  Reviewed
# 565    37.302167            0.8600  Reviewed
# 890    33.179833            0.3300  Reviewed
# 897    37.295333            1.0300  Reviewed
# 1129   37.231500            1.3600  Reviewed
# ...          ...               ...       ...
# 23407  38.391700            0.1898  Reviewed
# 23408  38.377700            0.2187  Reviewed
# 23409  36.917900            1.5200  Reviewed
# 23410  -9.028300            1.4300  Reviewed
# 23411  37.397300            0.9100  Reviewed
#
# [17352 rows x 3 columns]

# %%
df_1.shape
# Out:
# (23412, 3)

# %%
df_1.dropna(inplace=True)
# Out:
# /tmp/ipython-input-871821986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.dropna(inplace=True)

# %%
df_2 = temp_df[['Latitude', 'Root Mean Square', 'Status']]

# %%
df_2.fillna(0)
# Out:
#        Latitude  Root Mean Square     Status
# 0       19.2460            0.0000  Automatic
# 1        1.8630            0.0000  Automatic
# 2      -20.5790            0.0000  Automatic
# 3      -59.0760            0.0000  Automatic
# 4       11.9380            0.0000  Automatic
# ...         ...               ...        ...
# 23407   38.3917            0.1898   Reviewed
# 23408   38.3777            0.2187   Reviewed
# 23409   36.9179            1.5200   Reviewed
# 23410   -9.0283            1.4300   Reviewed
# 23411   37.3973            0.9100   Reviewed
#
# [23412 rows x 3 columns]

# %%
df_2.isnull().sum()
# Out:
# Latitude               0
# Root Mean Square    6060
# Status                 0
# dtype: int64

# %%
df_2.fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-1892046275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.fillna(0, inplace=True)

# %%
df_2.isnull().sum()
# Out:
# Latitude            0
# Root Mean Square    0
# Status              0
# dtype: int64

# %%
df_2[df['Root Mean Square'] >= 0]
# Out:
#         Latitude  Root Mean Square    Status
# 489    31.039500            0.6000  Reviewed
# 565    37.302167            0.8600  Reviewed
# 890    33.179833            0.3300  Reviewed
# 897    37.295333            1.0300  Reviewed
# 1129   37.231500            1.3600  Reviewed
# ...          ...               ...       ...
# 23407  38.391700            0.1898  Reviewed
# 23408  38.377700            0.2187  Reviewed
# 23409  36.917900            1.5200  Reviewed
# 23410  -9.028300            1.4300  Reviewed
# 23411  37.397300            0.9100  Reviewed
#
# [17352 rows x 3 columns]

# %%
df_2['Root Mean Square'].sample(10)
# Out:
# 17085    0.90
# 21775    0.96
# 1389     0.00
# 12967    1.00
# 6877     1.10
# 19878    1.02
# 16555    0.91
# 12082    0.80
# 5923     0.90
# 7463     1.00
# Name: Root Mean Square, dtype: float64

# %%
temp_df.sort_index()
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 0       19.2460   145.6160        6.0               NaN  Automatic
# 1        1.8630   127.3520        5.8               NaN  Automatic
# 2      -20.5790  -173.9720        6.2               NaN  Automatic
# 3      -59.0760   -23.5570        5.8               NaN  Automatic
# 4       11.9380   126.4270        5.8               NaN  Automatic
# ...         ...        ...        ...               ...        ...
# 23407   38.3917  -118.8941        5.6            0.1898   Reviewed
# 23408   38.3777  -118.8957        5.5            0.2187   Reviewed
# 23409   36.9179   140.4262        5.9            1.5200   Reviewed
# 23410   -9.0283   118.6639        6.3            1.4300   Reviewed
# 23411   37.3973   141.4103        5.5            0.9100   Reviewed
#
# [23412 rows x 5 columns]

# %%
temp_df.sort_values(by='Magnitude')
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 3165      7.409    -77.662        5.5               NaN   Reviewed
# 18368    -7.090    155.491        5.5              1.28   Reviewed
# 18365     1.409    125.763        5.5              0.89   Reviewed
# 18323    42.159    144.004        5.5              0.73   Reviewed
# 18350    -7.368    155.557        5.5              0.96   Reviewed
# ...         ...        ...        ...               ...        ...
# 17329     2.085     97.108        8.6              0.91   Reviewed
# 16       51.251    178.715        8.7               NaN  Automatic
# 19928   -36.122    -72.898        8.8              1.09   Reviewed
# 20501    38.297    142.373        9.1              1.16   Reviewed
# 17083     3.295     95.982        9.1              1.17   Reviewed
#
# [23412 rows x 5 columns]

# %%
temp_df.sort_values(by=['Magnitude', 'Root Mean Square'], ascending=[True, False])
# Out:
#        Latitude  Longitude  Magnitude  Root Mean Square     Status
# 22411    16.025    -95.649        5.5              2.10   Reviewed
# 19251   -56.920   -140.801        5.5              1.89   Reviewed
# 7058    -45.258    -75.711        5.5              1.70   Reviewed
# 10125   -31.003   -179.706        5.5              1.70   Reviewed
# 12552   -23.164    170.791        5.5              1.70   Reviewed
# ...         ...        ...        ...               ...        ...
# 17329     2.085     97.108        8.6              0.91   Reviewed
# 16       51.251    178.715        8.7               NaN  Automatic
# 19928   -36.122    -72.898        8.8              1.09   Reviewed
# 17083     3.295     95.982        9.1              1.17   Reviewed
# 20501    38.297    142.373        9.1              1.16   Reviewed
#
# [23412 rows x 5 columns]

# %%
df_1 = temp_df['Latitude']
df_2 = temp_df['Longitude']
df_3 = pd.concat([df_1, df_2], axis=0) # This will concatenate df_1 and df_2 vertically (along rows)
df_3
# Out:
# 0         19.2460
# 1          1.8630
# 2        -20.5790
# 3        -59.0760
# 4         11.9380
#            ...
# 23407   -118.8941
# 23408   -118.8957
# 23409    140.4262
# 23410    118.6639
# 23411    141.4103
# Length: 46824, dtype: float64

# %%
df_1 = temp_df[['Latitude', 'Magnitude']]
df_2 = temp_df['Longitude']
df_3 = pd.concat([df_1, df_2], axis=1)
df_3
# Out:
#        Latitude  Magnitude  Longitude
# 0       19.2460        6.0   145.6160
# 1        1.8630        5.8   127.3520
# 2      -20.5790        6.2  -173.9720
# 3      -59.0760        5.8   -23.5570
# 4       11.9380        5.8   126.4270
# ...         ...        ...        ...
# 23407   38.3917        5.6  -118.8941
# 23408   38.3777        5.5  -118.8957
# 23409   36.9179        5.9   140.4262
# 23410   -9.0283        6.3   118.6639
# 23411   37.3973        5.5   141.4103
#
# [23412 rows x 3 columns]

# %%
df_1 = temp_df[['Latitude', 'Magnitude']]
df_2 = temp_df[['Longitude', 'Root Mean Square']]
df_3 = pd.merge(df_1, df_2, left_index=True, right_index=True) # This will merge df_1 and df_2 on their indices
df_3
# Out:
#        Latitude  Magnitude  Longitude  Root Mean Square
# 0       19.2460        6.0   145.6160               NaN
# 1        1.8630        5.8   127.3520               NaN
# 2      -20.5790        6.2  -173.9720               NaN
# 3      -59.0760        5.8   -23.5570               NaN
# 4       11.9380        5.8   126.4270               NaN
# ...         ...        ...        ...               ...
# 23407   38.3917        5.6  -118.8941            0.1898
# 23408   38.3777        5.5  -118.8957            0.2187
# 23409   36.9179        5.9   140.4262            1.5200
# 23410   -9.0283        6.3   118.6639            1.4300
# 23411   37.3973        5.5   141.4103            0.9100
#
# [23412 rows x 4 columns]

# %%
# Example on pandas merge
df1 = pd.DataFrame({
    'key': ['K0', 'K1', 'K2', 'K3'],
    'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
    'Age': [27, 24, 22, 32]
})

df2 = pd.DataFrame({
    'key': ['K0', 'K1', 'K2', 'K4'],
    'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj']
})

merged_df = pd.merge(df1, df2, on='key', how='outer')
print(merged_df)
# Out:
#   key    Name   Age    Address
# 0  K0     Jai  27.0     Nagpur
# 1  K1  Princi  24.0     Kanpur
# 2  K2  Gaurav  22.0  Allahabad
# 3  K3    Anuj  32.0        NaN
# 4  K4     NaN   NaN    Kannuaj

# %%
temp_df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Magnitude', 'Root Mean Square', 'Status'], dtype='object')

# %%
temp_df.groupby('Status').mean()
# Out:
#             Latitude  Longitude  Magnitude  Root Mean Square
# Status
# Automatic  10.252843  54.164980   6.005616               NaN
# Reviewed    0.589817  37.794704   5.866894          1.022784

# %%
temp_df.groupby('Status')[['Latitude', 'Magnitude']].mean()
# Out:
#             Latitude  Magnitude
# Status
# Automatic  10.252843   6.005616
# Reviewed    0.589817   5.866894

# %%
grouped = temp_df.groupby('Status').agg({'Magnitude': 'mean', 'Root Mean Square': 'sum'}) # This will group the DataFrame by the 'Status' column and calculate the mean of 'Magnitude' and the sum of 'Root Mean Square' for each group
grouped
# Out:
#            Magnitude  Root Mean Square
# Status
# Automatic   6.005616            0.0000
# Reviewed    5.866894        17747.3478

# %%
result = temp_df.groupby('Status').agg({
    'Magnitude': ['mean', 'min'],
    'Root Mean Square': ['sum', 'max']
}) # This will group the DataFrame by the 'Status' column and calculate the mean and min of 'Magnitude' and the sum and max of 'Root Mean Square' for each group
result
# Out:
#           Magnitude      Root Mean Square
#                mean  min              sum   max
# Status
# Automatic  6.005616  5.5           0.0000   NaN
# Reviewed   5.866894  5.5       17747.3478  3.44

# %%
def prod_two(group):
    # This function calculates the weighted average of 'Magnitude' using 'Root Mean Square' as weights
    return (group['Magnitude'] * group['Root Mean Square']).sum() / group['Root Mean Square'].sum()

result = temp_df.groupby('Status').apply(prod_two)  # This will apply the prod_two function to each group in the DataFrame grouped by 'Status'
print(result)
# Out:
# Status
# Automatic        NaN
# Reviewed     5.88161
# dtype: float64
# /tmp/ipython-input-928527070.py:3: RuntimeWarning: invalid value encountered in scalar divide
#   return (group['Magnitude'] * group['Root Mean Square']).sum() / group['Root Mean Square'].sum()
# /tmp/ipython-input-928527070.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = temp_df.groupby('Status').apply(prod_two)  # This will apply the prod_two function to each group in the DataFrame grouped by 'Status'

# %%
ex_df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Jake'],
    'Age': [28, 34, 29],
    'City': ['NY', 'LA', 'SF']
})

ex_df
# Out:
#    Name  Age City
# 0  John   28   NY
# 1  Jane   34   LA
# 2  Jake   29   SF

# %%
df2 = ex_df.set_index('Name')
print(df2)
# Out:
#       Age City
# Name
# John   28   NY
# Jane   34   LA
# Jake   29   SF

# %%
df2.reset_index(drop=False, inplace=False)
# Out:
#    Name  Age City
# 0  John   28   NY
# 1  Jane   34   LA
# 2  Jake   29   SF

# %%
df2.reset_index(drop=False, inplace=True)

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Name  Age City
# 0  John   28   NY
# 1  Jane   34   LA
# 2  Jake   29   SF

# %%
temp_df.to_csv('data.csv', index=True)

# %%
exam = pd.read_csv('data.csv') # This will read the CSV file 'data.csv' into a DataFrame named exam
exam.head()
# Out:
#    Unnamed: 0  Latitude  Longitude  Magnitude  Root Mean Square     Status
# 0           0    19.246    145.616        6.0               NaN  Automatic
# 1           1     1.863    127.352        5.8               NaN  Automatic
# 2           2   -20.579   -173.972        6.2               NaN  Automatic
# 3           3   -59.076    -23.557        5.8               NaN  Automatic
# 4           4    11.938    126.427        5.8               NaN  Automatic

# %% [markdown]
# Matplotlib **Library**

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
import pandas as pd

# Upload CSV file
uploaded = files.upload()

# Read CSV (replace 'your_file.csv' with the uploaded filename)
df = pd.read_csv("car_price.csv")
print(df.head())
# Out:
#      <input type="file" id="files-b651ce44-adbb-4f80-bee1-8b29183390b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b651ce44-adbb-4f80-bee1-8b29183390b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_ID', 'symboling', 'CarName', 'fueltype',
#        'aspiration', 'doornumber', 'carbody', 'drivewheel', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.sample(5)
# Out:
#      car_ID  symboling            CarName fueltype aspiration doornumber  \
# 195     196         -1        volvo 144ea      gas        std       four
# 99      100          0       nissan rogue      gas        std       four
# 51       52          1   maxda glc deluxe      gas        std        two
# 185     186          2  volkswagen type 3      gas        std       four
# 140     141          2          subaru dl      gas        std        two
#
#        carbody drivewheel  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 195      wagon        rwd      104.3      188.8  ...         141        mpfi
# 99   hatchback        fwd       97.2      173.4  ...         120        2bbl
# 51   hatchback        fwd       93.1      159.1  ...          91        2bbl
# 185      sedan        fwd       97.3      171.7  ...         109        mpfi
# 140  hatchback        4wd       93.3      157.3  ...         108        2bbl
#
# ...

# %%
df.set_index('car_ID', inplace=True)
df.sample(5)
# Out:
#         symboling           CarName fueltype aspiration doornumber    carbody  \
# car_ID
# 76              1    mercury cougar      gas      turbo        two  hatchback
# 52              1  maxda glc deluxe      gas        std        two  hatchback
# 202            -1       volvo 144ea      gas      turbo       four      sedan
# 53              1   mazda rx2 coupe      gas        std        two  hatchback
# 175            -1  toyota celica gt   diesel      turbo       four      sedan
#
#        drivewheel  wheelbase  carlength  carwidth  ...  enginesize  \
# car_ID                                             ...
# 76            rwd      102.7      178.4      68.0  ...         140
# 52            fwd       93.1      159.1      64.2  ...          91
# 202           rwd      109.1      188.8      68.8  ...         141
# 53            fwd       93.1      159.1      64.2  ...          91
# 175           fwd      102.4      175.6      66.5  ...         110
#
# ...

# %%
df.sort_index(inplace=True)

# %%
df[['enginesize', 'horsepower']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 1 to 205
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   enginesize  205 non-null    int64
#  1   horsepower  205 non-null    int64
# dtypes: int64(2)
# memory usage: 4.8 KB

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower']);

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])
plt.show()

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])
plt.title('Scatter plot of horsepower of car versus engine size')
# Out:
# Text(0.5, 1.0, 'Scatter plot of horsepower of car versus engine size')

# %%
plt.scatter(x=df['enginesize'], y=df['horsepower'])
plt.title('Scatter plot of horsepower of car versus engine size')
plt.xlabel('size of engine')
plt.ylabel('horsepower')
plt.show()

# %%
plt.scatter(x=df['citympg'], y=df['horsepower'], s=10, marker='^') # 's' controls size of points & 'marker' controls shape
plt.title('Scatter plot of horsepower of car versus city mileage')
plt.xlabel('city mileage')
plt.ylabel('horsepower')
plt.show()

# %%
plt.scatter(x=df['citympg'], y=df['horsepower'], s=50, marker='^', alpha=0.5, c = 'r') # 'alpha' controls transparency and 'c' controls color
plt.title('Scatter plot of horsepower of car versus city mileage')
plt.xlabel('city mileage')
plt.ylabel('horsepower')
plt.show()

# %%
df_ap = pd.read_csv('AirPassengers.csv')

# %%
df_ap.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
df_ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
import matplotlib.pyplot as plt

plt.plot(df_ap['Month'], df_ap['Passengers'])  # Line plot of month vs number of passengers
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.show()

# %%
plt.plot(df_ap['Month'],df_ap['Passengers'])
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24)) # Adjust x-ticks to show every 2 years
plt.show()

# %%
plt.plot(df_ap['Month'],df_ap['Passengers'],marker='o') # marker='o' adds points to the line plot
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24))
plt.show()

# %%
# Reshaping the size of the canvas for better visibility
plt.figure(figsize=(10,4)) # Set figure size for better visibility
plt.plot(df_ap['Month'],df_ap['Passengers'],marker='o')
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24))
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(df_ap['Month'], df_ap['Passengers'], marker='o', markersize=5) # markersize controls the size of the markers
plt.title('Line Plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24))
plt.xlim(75, 140) # Adjust x-axis limits to focus on a specific range
plt.ylim(300, 500);

# %%
print(df_ap.columns)
# Out:
# Index(['Month', 'Passengers'], dtype='object')

# %%
plt.hist(df['price']) # Histogram of car prices
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2607764872.py in <cell line: 0>()
# ----> 1 plt.hist(df['price']) # Histogram of car prices
# ...

# %%
print(df.columns)
# Out:
# Index(['Month', 'Passengers'], dtype='object')

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a8216e9-5ea0-4f77-a2f9-eda27a546cd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a8216e9-5ea0-4f77-a2f9-eda27a546cd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("car_price.csv")

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'car_ID', 'symboling', 'CarName', 'fueltype',
#        'aspiration', 'doornumber', 'carbody', 'drivewheel', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.hist(df['price'], bins=30, edgecolor='black')  # Added bins + edgecolor for better visualization
plt.xlabel('Price')
plt.ylabel('Number of cars')
plt.title('Distribution of car prices')
plt.show()

# %%
plt.hist(df['price'], bins=5) # Histogram of car prices with 5 bins
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars');

# %%
plt.hist(df['price'], bins=10) # Histogram of car prices with 5 bins
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars');

# %%
two_door_df = df[df['doornumber'] == 'two'] # Filter for two-door cars
four_door_df = df[df['doornumber'] == 'four']

# %%
# Q. How are the prices of cars distributed based on the number of doors?
plt.hist(two_door_df['price'])
plt.hist(four_door_df['price'])
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors');

# %%
plt.hist(two_door_df['price'], label='Two')
plt.hist(four_door_df['price'], label='Four')
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors')
plt.legend();

# %%
plt.hist(two_door_df['price'], label='Two')
plt.hist(four_door_df['price'], label='Four')
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors')
plt.legend();

# %%
# Stacked histogram to compare the distribution of prices for two-door and four-door cars
plt.hist([two_door_df['price'], four_door_df['price']], alpha=0.5,label=['two door', 'four door'], stacked=True)
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors')
plt.legend();

# %%
fig, ax = plt.subplots()

# %%
# Q. How are the prices of two-door and four-door cars distributed?
fig, axs = plt.subplots(1, 2, figsize = (8,4)) # Create a figure with 1 row and 2 columns of subplots
axs[0].hist(two_door_df['price'], bins=20, color='blue') # Histogram of two-door car prices
axs[0].set_title('Histogram of prices of two door cars') # Set title for the first subplot

axs[0].set_xlabel('price')
axs[0].set_ylabel('frequency')
axs[0].tick_params(axis='x', rotation=45) # Rotate x-axis labels for better readability

axs[1].hist(four_door_df['price'], bins = 20, color = 'green') # Histogram of four-door car prices
axs[1].set_title("Histograms of prices of four door cars")

axs[1].set_xlabel('price')
axs[1].set_ylabel('frequency')
axs[1].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

plt.suptitle('Histograms of prices of two door and four door cars') # Set a common title for the entire figure
plt.tight_layout();

# %%
# Q. How are the cars distributed over different values of the doornumber feature?
df['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
doornumber_value_counts = df['doornumber'].value_counts()

# %%
plt.pie(doornumber_value_counts)
plt.title('Pie chart of distribution of cars based on number of doors')
plt.show()

# %%
plt.pie(doornumber_value_counts.values, labels=doornumber_value_counts.index) # Pie chart with labels for better understanding
plt.title('Pie chart of distribution of cars based on number of doors')
plt.show()

# %%
pie_labels = [doornumber_value_counts.index[0] + ' ' + str(doornumber_value_counts.iloc[0]),
              doornumber_value_counts.index[1] + ' ' + str(doornumber_value_counts.iloc[1])]
pie_labels
# Out:
# ['four 115', 'two 90']

# %%
plt.pie(doornumber_value_counts.values, labels=pie_labels)
plt.title('Pie chart of distribution of cars based on number of doors');

# %%
carbody_value_counts = df['carbody'].value_counts()
carbody_value_counts
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar(carbody_value_counts.index, carbody_value_counts.values) #
ax.set_xlabel('Types of Cars based on car body')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car body');

# %%
# Q How are the cars distributed over the different values of the cylindernumber feature?
df['cylindernumber'].value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
cylindernumber_value_counts = df['cylindernumber'].value_counts() # Count the occurrences of each value in the 'cylindernumber' column
cylindernumber_value_counts
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar(cylindernumber_value_counts.index, cylindernumber_value_counts.values)
ax.set_xlabel('Types of cars based on number of cylinders')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car based on number of cylinders');

# %%
fig, ax = plt.subplots()
ax.bar(cylindernumber_value_counts.index, cylindernumber_value_counts.values)
ax.set_xlabel('Types of cars based on number of cylinders')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car based on number of cylinders')
# ax.grid(); # Add grid lines for better readability
# ax.xaxis.grid(); # Add grid lines to the x-axis for better readability
ax.yaxis.grid();

# %%
average_prices = df.groupby('carbody')['price'].mean()
average_prices
# Out:
# carbody
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10376.652386
# sedan          14344.270833
# wagon          12371.960000
# Name: price, dtype: float64

# %%
# Bar graph of average price of different types of cars based on car body
plt.bar(average_prices.index, average_prices.values) # Bar graph of average prices
plt.title('Average price of different types of cars based on car body')
plt.xlabel('carbody')
plt.ylabel('price')
plt.grid(axis='y');

# %%
plt.bar(average_prices.index, average_prices.values)
plt.title('Average price of different types of cars based on car body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.grid(axis='y') # Add grid lines to the y-axis for better readability
plt.xticks(rotation = 45);

# %%
average_prices_sorted = average_prices.sort_values()

# %%
plt.bar(average_prices_sorted.index, average_prices_sorted.values)
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='y');

# %%
average_prices_sorted = average_prices.sort_index()

# %%
plt.bar(average_prices_sorted.index, average_prices_sorted.values)
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='y');

# %%
plt.barh(average_prices_sorted.index, average_prices_sorted.values) # Horizontal bar graph of average prices
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='x');

# %%
# Q. How are the cars in the data set distributed over `doornumber` and `carbody`?
doornumber_carbody_crosstable = pd.crosstab(df['doornumber'], df['carbody'])
doornumber_carbody_crosstable
# Out:
# carbody     convertible  hardtop  hatchback  sedan  wagon
# doornumber
# four                  0        0         10     80     25
# two                   6        8         60     16      0

# %%
carbody_categories = doornumber_carbody_crosstable.columns
carbody_categories
# Out:
# Index(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'], dtype='object', name='carbody')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'])
bar2 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'])
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Carbody vs Doornumber')
ax.legend(['Four doors', 'Two doors'])
plt.show()

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'], alpha=0.5)
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'], alpha=0.5)
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
# Grouped bar plot to visualize the distribution of cars based on number of doors and type of car body by controlling the width of the bars
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'], width=0.5)
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'],width=0.5)
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
# Grouped bar plot to visualize the distribution of cars based on number of doors and type of car body adjusting the position of the bars
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories))-0.25, doornumber_carbody_crosstable.loc['four'], width=0.5) # move bars to the left
bar1 = ax.bar(np.arange(len(carbody_categories))+0.25, doornumber_carbody_crosstable.loc['two'], width=0.5) # move bars to the right
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories))-0.2, doornumber_carbody_crosstable.loc['four'], width=0.4,label='four') # move bars to the left and control width
bar1 = ax.bar(np.arange(len(carbody_categories))+0.2, doornumber_carbody_crosstable.loc['two'], width=0.4,label='two') # move bars to the right and control width
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body')
ax.legend();
